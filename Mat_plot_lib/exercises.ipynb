# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color = 'red', linewidth=1)
ax.set_ylabel('0-100')
ax.set_title('Traine graphic')
# Out:
# Text(0.5, 1.0, 'Traine graphic')
